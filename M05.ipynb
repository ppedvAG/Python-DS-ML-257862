# %% [markdown]
# # Matplotlib
# Hauptwerkzeug zur Visualierung von Daten
#
# https://matplotlib.org/stable/plot_types/index.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Data/AmazonStock.csv")

# %%
data
# Out:
#             Date        Open        High        Low       Close   Adj Close  \
# 0     2013-03-25   12.929000   12.971500  12.725000   12.801000   12.801000
# 1     2013-03-26   12.852500   13.074000  12.814000   13.015500   13.015500
# 2     2013-03-27   12.937500   13.296500  12.895000   13.265000   13.265000
# 3     2013-03-28   13.291000   13.369000  13.203000   13.324500   13.324500
# 4     2013-04-01   13.349000   13.370000  13.050500   13.080500   13.080500
# ...          ...         ...         ...        ...         ...         ...
# 2514  2023-03-20   98.410004   98.480003  95.699997   97.709999   97.709999
# 2515  2023-03-21   98.139999  100.849998  98.000000  100.610001  100.610001
# 2516  2023-03-22  100.449997  102.099998  98.610001   98.699997   98.699997
# 2517  2023-03-23  100.430000  101.059998  97.620003   98.709999   98.709999
# 2518  2023-03-24   98.070000   98.300003  96.400002   98.129997   98.129997
#
#         Volume
# 0     50278000
# 1     48420000
# ...

# %%
data.plot() # Nicht Aussagekräftig mit allen Spalten
# Out:
# <Axes: >

# %%
data["Open"].plot()
# Out:
# <Axes: >

# %%
data.loc[:, ("Open", "Close")].plot()
# Out:
# <Axes: >

# %%
(data["Open"]-data["Close"]).plot()
# Out:
# <Axes: >

# %%
(data.loc[:101,"Open"]-data.loc[:101,"Close"]).plot()
# Out:
# <Axes: >

# %%
plt.plot(data["Open"], color="red",ls=":")

# %%
pop = pd.read_csv("Data/PopulationDataFertig.csv", index_col="Country")[:10]

# %%
pop
# Out:
#                Population  YearlyChange  NetChange  Density  LandArea  \
# Country
# China          1439323776          0.39    5540090      153   9388211
# India          1380004385          0.99   13586631      464   2973190
# United States   331002651          0.59    1937734       36   9147420
# Indonesia       273523615          1.07    2898047      151   1811570
# Pakistan        220892340          2.00    4327022      287    770880
# Brazil          212559417          0.72    1509890       25   8358140
# Nigeria         206139589          2.58    5175990      226    910770
# Bangladesh      164689383          1.01    1643222     1265    130170
# Russia          145934462          0.04      62206        9  16376870
# Mexico          128932753          1.06    1357224       66   1943950
#
#                Migrants  FertRate  MedAge  UrbanPopPct  WorldSharePct
# Country
# China           -348399       1.7      38           61          18.47
# ...

# %%
plt.pie(pop["WorldSharePct"], labels=pop.index, explode=np.ones(10)*0.02, rotatelabels=True)
None

# %% [markdown]
# ## Globaler vs Objektorienterter Modus
#
# Globaler Modus: Befehle ausführn über plt, mit plt.show() die Konfiguration abschließen
#
# Objektorientierter Modus: Figure Objekte und Axis Objekte werden dediziert angesprochen und dadurch konfiguriert

# %%
plt.plot(pop["Population"])
plt.grid(alpha=0.2)
plt.show() # Schließt die Konfiguration des Plot ab und zeigt ihn an

plt.plot(pop["WorldSharePct"])
plt.show()

# %%
plt.figure(figsize = (12,10))
plt.plot(pop["Population"])
plt.show()

# %%
fig, ((ax1_1, ax1_2), (ax2_1, ax2_2)) = plt.subplots(2,2)
ax1_1.plot(np.random.random(100))
ax1_2.pie(pop["WorldSharePct"])
ax2_1.bar(pop.index, pop["Population"])
ax2_2.hist(np.random.randint(100, size=100), bins=20)
fig.savefig("Test.png")
None

# %% [markdown]
# ### Plot Speichern
# plt.savefig("Name")

# %%
plt.savefig("Test.png")
