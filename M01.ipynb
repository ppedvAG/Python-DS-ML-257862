# %% [markdown]
# IPython
#
# Entwicklungumgebung, in der Ergebnisse in Zellen gespeichert werden
# Ergebnisse der vorherigen Zellen könenn später in anderen Zellen verwendet werden.
#
# Markdown Zellen zur Dokumentation
# Code Zellen zum Ausführen
#
# Imports bleiben über mehrere Zellen

# %%
# das hier ist eine Codezelle
x=5

# %%
x*2
# Out:
# 10

# %%
x
# Out:
# 5

# %% [markdown]
# Pandas zum verarbeiten von Daten

# %%
import pandas as pd

# %%
pd.DataFrame({"Spalte1": [1,2,3], "Spalte2": [4,5,6],"Spalte3":[7,8,9]})
# Out:
#    Spalte1  Spalte2  Spalte3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %%
import matplotlib.pyplot as plt

# %%
y = [30,6,2,6,8,1,0]
plt.plot(y)
